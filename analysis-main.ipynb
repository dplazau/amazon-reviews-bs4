# %%
import pandas as pd

# %%
df = pd.read_csv("./TAPONES-2022-04-19-22-52-50.csv")

# %%
df.head(20)
# Out:
#                                            item_title  \
# 0                                               Un 10
# 1                                  Recomiendo 100%100
# 2              Gran aislamiento y buena presentación.
# 3                        Los que más aislan del ruido
# 4                                    Aíslan de verdad
# 5                          Los mejores que he probado
# 6                               Perfectos para dormir
# 7                                 Aislamiento potente
# 8                    El otorrino nos los ha prohibido
# 9                                Piso con subnormales
# 10                                  No los recomiendo
# 11                          Se rompen dentro del oído
# 12                                         PELIGROSOS
# 13                                Una absoluta estafa
# 14                                  Tapones malísimos
# 15  No más picores, irritaciones de orejas ni otit...
# ...
